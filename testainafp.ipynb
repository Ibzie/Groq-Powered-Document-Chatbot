# %%
# !pip install pdfplumber
# !pip install unstructured
# Out:
# Collecting pdfplumber
#   Obtaining dependency information for pdfplumber from https://files.pythonhosted.org/packages/ee/ec/315015b6c4667d889cc14348c93e31f9fd43a6f61162b85c39e4a21018d5/pdfplumber-0.11.0-py3-none-any.whl.metadata
#   Using cached pdfplumber-0.11.0-py3-none-any.whl.metadata (39 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Obtaining dependency information for pdfminer.six==20231228 from https://files.pythonhosted.org/packages/eb/9c/e46fe7502b32d7db6af6e36a9105abb93301fa1ec475b5ddcba8b35ae23a/pdfminer.six-20231228-py3-none-any.whl.metadata
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from pdfplumber) (10.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Obtaining dependency information for pypdfium2>=4.18.0 from https://files.pythonhosted.org/packages/e1/bf/460372a90eb11efcd2db2e7b8c07a36dfd91978d73f6f946c8d6798f108b/pypdfium2-4.29.0-py3-none-win_amd64.whl.metadata
#   Using cached pypdfium2-4.29.0-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (42.0.6)
# Requirement already satisfied: cffi>=1.12 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Using cached pdfplumber-0.11.0-py3-none-any.whl (56 kB)
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached pypdfium2-4.29.0-py3-none-win_amd64.whl (2.9 MB)
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.0 pypdfium2-4.29.0
# Could not find platform independent libraries <prefix>
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting unstructured
#   Obtaining dependency information for unstructured from https://files.pythonhosted.org/packages/a7/50/e2c2222d89a2f88e1d5f3a0f9891a94c7d67ae77ec4d29c5c17fd37d0dfd/unstructured-0.11.8-py3-none-any.whl.metadata
#   Downloading unstructured-0.11.8-py3-none-any.whl.metadata (26 kB)
# Collecting chardet (from unstructured)
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured)
#   Obtaining dependency information for filetype from https://files.pythonhosted.org/packages/18/79/1b8fa1bb3568781e84c9200f951c735f3f157429f44be0495da55894d620/filetype-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Obtaining dependency information for python-magic from https://files.pythonhosted.org/packages/6c/73/9f872cb81fc5c3bb48f7227872c28975f998f3e7c2b1c16e95e6432bbb90/python_magic-0.4.27-py2.py3-none-any.whl.metadata
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/37/a5/7b2e6152aefa0632871f77a202bb68eac52037e4498a6901be0f0458ffdc/lxml-5.2.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached lxml-5.2.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: nltk in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured) (3.8.1)
# Collecting tabulate (from unstructured)
#   Obtaining dependency information for tabulate from https://files.pythonhosted.org/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl.metadata
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: requests in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Obtaining dependency information for emoji from https://files.pythonhosted.org/packages/bd/48/508a980e9c9f12dbc2e45e57f027abdd92320e5be37c5c551588a86acb48/emoji-2.11.1-py2.py3-none-any.whl.metadata
#   Downloading emoji-2.11.1-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: dataclasses-json in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured) (0.6.5)
# Collecting python-iso639 (from unstructured)
#   Obtaining dependency information for python-iso639 from https://files.pythonhosted.org/packages/01/08/5e649cf18dec750d498c53c6c8eb1d9790752ebd50fa7f7e69cc0c277cfe/python_iso639-2024.4.27-py3-none-any.whl.metadata
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 10.2/981.5 kB ? eta -:--:--
#      - ----------------------------------- 30.7/981.5 kB 435.7 kB/s eta 0:00:03
#      - ----------------------------------- 41.0/981.5 kB 388.9 kB/s eta 0:00:03
#      - ----------------------------------- 41.0/981.5 kB 388.9 kB/s eta 0:00:03
#      - ----------------------------------- 41.0/981.5 kB 388.9 kB/s eta 0:00:03
#      - ----------------------------------- 41.0/981.5 kB 388.9 kB/s eta 0:00:03
#      - ----------------------------------- 51.2/981.5 kB 137.9 kB/s eta 0:00:07
#      --- --------------------------------- 92.2/981.5 kB 249.0 kB/s eta 0:00:04
#      ---- ------------------------------- 112.6/981.5 kB 273.1 kB/s eta 0:00:04
#      ---- ------------------------------- 122.9/981.5 kB 276.8 kB/s eta 0:00:04
#      ---- ------------------------------- 122.9/981.5 kB 276.8 kB/s eta 0:00:04
#      ---- ------------------------------- 122.9/981.5 kB 276.8 kB/s eta 0:00:04
#      ---- ------------------------------- 122.9/981.5 kB 276.8 kB/s eta 0:00:04
#      ----- ------------------------------ 143.4/981.5 kB 218.2 kB/s eta 0:00:04
#      ------ ----------------------------- 184.3/981.5 kB 265.0 kB/s eta 0:00:04
#      --------- -------------------------- 256.0/981.5 kB 349.1 kB/s eta 0:00:03
#      --------- -------------------------- 256.0/981.5 kB 349.1 kB/s eta 0:00:03
#      --------- -------------------------- 256.0/981.5 kB 349.1 kB/s eta 0:00:03
#      --------- -------------------------- 256.0/981.5 kB 349.1 kB/s eta 0:00:03
#      --------- -------------------------- 266.2/981.5 kB 282.2 kB/s eta 0:00:03
#      ----------- ------------------------ 317.4/981.5 kB 327.5 kB/s eta 0:00:03
#      -------------- --------------------- 389.1/981.5 kB 384.6 kB/s eta 0:00:02
#      ----------------- ------------------ 481.3/981.5 kB 456.4 kB/s eta 0:00:02
#      ------------------ ----------------- 512.0/981.5 kB 479.2 kB/s eta 0:00:01
#      ------------------ ----------------- 512.0/981.5 kB 479.2 kB/s eta 0:00:01
#      ------------------ ----------------- 512.0/981.5 kB 479.2 kB/s eta 0:00:01
#      -------------------- --------------- 563.2/981.5 kB 453.6 kB/s eta 0:00:01
#      ----------------------- ------------ 634.9/981.5 kB 493.4 kB/s eta 0:00:01
#      --------------------------- -------- 747.5/981.5 kB 561.5 kB/s eta 0:00:01
#      -------------------------------- --- 880.6/981.5 kB 640.0 kB/s eta 0:00:01
#      ------------------------------------ 981.5/981.5 kB 698.2 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured) (1.26.4)
# Collecting rapidfuzz (from unstructured)
#   Obtaining dependency information for rapidfuzz from https://files.pythonhosted.org/packages/80/9f/d787dcdb1a578af6734f76c18b0e178bb307b08a78293498e875f1d44e3a/rapidfuzz-3.9.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading rapidfuzz-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting backoff (from unstructured)
#   Obtaining dependency information for backoff from https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl.metadata
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured) (4.11.0)
# Collecting unstructured-client (from unstructured)
#   Obtaining dependency information for unstructured-client from https://files.pythonhosted.org/packages/b0/bc/c74937363c2657a77e4c4e105b7a004203ad53f128b5caf5dbb9dc9458d1/unstructured_client-0.22.0-py3-none-any.whl.metadata
#   Downloading unstructured_client-0.22.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting wrapt (from unstructured)
#   Obtaining dependency information for wrapt from https://files.pythonhosted.org/packages/5c/cc/8297f9658506b224aa4bd71906447dea6bb0ba629861a758c28f67428b91/wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>1.2 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from dataclasses-json->unstructured) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from nltk->unstructured) (2024.4.28)
# Requirement already satisfied: tqdm in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from nltk->unstructured) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from requests->unstructured) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from requests->unstructured) (2024.2.2)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured)
#   Obtaining dependency information for deepdiff>=6.0 from https://files.pythonhosted.org/packages/18/e6/d27d37dc55dbf40cdbd665aa52844b065ac760c9a02a02265f97ea7a4256/deepdiff-7.0.1-py3-none-any.whl.metadata
#   Downloading deepdiff-7.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured)
#   Obtaining dependency information for jsonpath-python>=1.0.6 from https://files.pythonhosted.org/packages/16/8a/d63959f4eff03893a00e6e63592e3a9f15b9266ed8e0275ab77f8c7dbc94/jsonpath_python-1.0.6-py3-none-any.whl.metadata
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mypy-extensions>=1.0.0 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured-client->unstructured) (23.2)
# Requirement already satisfied: pypdf>=4.0 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured-client->unstructured) (4.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Collecting ordered-set<4.2.0,>=4.1.0 (from deepdiff>=6.0->unstructured-client->unstructured)
#   Obtaining dependency information for ordered-set<4.2.0,>=4.1.0 from https://files.pythonhosted.org/packages/33/55/af02708f230eb77084a299d7b08175cff006dea4f2721074b92cdb0296c0/ordered_set-4.1.0-py3-none-any.whl.metadata
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: colorama in d:\projects\ai-powered-chatbot-on-dnd-based-combat-algorithms\ai-env\lib\site-packages (from click->nltk->unstructured) (0.4.6)
# Downloading unstructured-0.11.8-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.8 MB 6.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.8 MB 6.6 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.8 MB 6.4 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.8 MB 6.2 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.8 MB 6.2 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.8 MB 6.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.8 MB 3.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.5/1.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.9 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    --------------------------------------- 199.4/199.4 kB 11.8 MB/s eta 0:00:00
# Downloading emoji-2.11.1-py2.py3-none-any.whl (433 kB)
#    ---------------------------------------- 0.0/433.8 kB ? eta -:--:--
#    -------------------- ------------------- 225.3/433.8 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 433.8/433.8 kB 5.4 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached lxml-5.2.1-cp312-cp312-win_amd64.whl (3.8 MB)
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ---------------------------------------- 0.0/274.7 kB ? eta -:--:--
#    -------------------------------------- - 266.2/274.7 kB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 274.7/274.7 kB 5.6 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading rapidfuzz-3.9.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.6 MB 9.9 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.6 MB 6.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.2/1.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.8 MB/s eta 0:00:00
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading unstructured_client-0.22.0-py3-none-any.whl (28 kB)
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Downloading deepdiff-7.0.1-py3-none-any.whl (80 kB)
#    ---------------------------------------- 0.0/80.8 kB ? eta -:--:--
#    ---------------------------------------- 80.8/80.8 kB 4.7 MB/s eta 0:00:00
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993255 sha256=a3b6a5cbb2a781c1937bae4e3baed120a5a3791d4fec0e23a9afdc04ea653e97
#   Stored in directory: c:\users\ibzcl\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: filetype, wrapt, tabulate, rapidfuzz, python-magic, python-iso639, ordered-set, lxml, langdetect, jsonpath-python, emoji, chardet, backoff, deepdiff, unstructured-client, unstructured
# Successfully installed backoff-2.2.1 chardet-5.2.0 deepdiff-7.0.1 emoji-2.11.1 filetype-1.2.0 jsonpath-python-1.0.6 langdetect-1.0.9 lxml-5.2.1 ordered-set-4.1.0 python-iso639-2024.4.27 python-magic-0.4.27 rapidfuzz-3.9.0 tabulate-0.9.0 unstructured-0.11.8 unstructured-client-0.22.0 wrapt-1.16.0
# Could not find platform independent libraries <prefix>
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain.document_loaders import DirectoryLoader

DATA_PATH = ""

def load_documents():
    loader = DirectoryLoader(DATA_PATH, glob="*.txt")
    documents = loader.load()
    return documents

documents = load_documents()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.document_loaders import DirectoryLoader
#       3 DATA_PATH = ""
#       5 def load_documents():
#
# File D:\Projects\Ai-Powered-Chatbot-on-DnD-Based-Combat-Algorithms\AI-Env\Lib\site-packages\langchain\document_loaders\__init__.py:32, in __getattr__(name)
#      31 def __getattr__(name: str) -> Any:
# ---> 32     from langchain_community import document_loaders
#      34     # If not in interactive env, raise warning.
#      35     if not is_interactive_env():
#
# File D:\Projects\Ai-Powered-Chatbot-on-DnD-Based-Combat-Algorithms\AI-Env\Lib\site-packages\langchain_community\document_loaders\__init__.py:163
#     149 from langchain_community.document_loaders.org_mode import UnstructuredOrgModeLoader
#     150 from langchain_community.document_loaders.pdf import (
#     151     AmazonTextractPDFLoader,
#     152     MathpixPDFLoader,
#    (...)
#     161     UnstructuredPDFLoader,
#     162 )
# --> 163 from langchain_community.document_loaders.pebblo import PebbloSafeLoader
#     164 from langchain_community.document_loaders.polars_dataframe import PolarsDataFrameLoader
#     165 from langchain_community.document_loaders.powerpoint import UnstructuredPowerPointLoader
#
# File D:\Projects\Ai-Powered-Chatbot-on-DnD-Based-Combat-Algorithms\AI-Env\Lib\site-packages\langchain_community\document_loaders\pebblo.py:5
#       3 import logging
#       4 import os
# ----> 5 import pwd
#       6 import uuid
#       7 from http import HTTPStatus
#
# ModuleNotFoundError: No module named 'pwd'
